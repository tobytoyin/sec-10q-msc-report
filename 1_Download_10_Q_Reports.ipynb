# %% [markdown]
# <a href="https://colab.research.google.com/github/tobytoyin/sec-10q-msc-report/blob/main/1_Download_10_Q_Reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, I will be using beautifulsoup and requests to download all the sec 10-q filings.

# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup
import time
import numpy as np
import os 
import re

## retrieve the selected company 
selected_companies = pd.read_csv('/content/drive/MyDrive/Aston/Term 3/data/selected_companies.csv')

# extracted records 
extracted_records = pd.read_csv('/content/drive/MyDrive/Aston/Term 3/data/edgar-filing-new.csv')
extracted_companies = extracted_records.groupby('sym').count()

# %%
resp = requests.get('https://free-proxy-list.net/')
df = pd.read_html(resp.text)[0].dropna()
proxies = list('https://' + df['IP Address'].astype(str) + ':' + df['Port'].astype(int).astype(str))
get_proxy = 0

# %%
def polite_try(url, try_n=10, sleep=5, **kwargs):
  """Retry politely"""
  global get_proxy
  trial = 0

  while(trial <= try_n):
      # make request 
      response = requests.get(url, **kwargs)
      
      # check if the request is okay
      if response.status_code == 200:
        return response
      
      # if fail, add trial by 1
      trial += 1
      print(f'--- failure - retry ({trial}/{try_n})')
      print(response.status_code)

      # wait for 60s before next try
      time.sleep(sleep)
      get_proxy += 1

  return None


### A class to download from Edgar
class Downloader:
  def __init__(self, sym, cik, type_):
    self.sym = sym
    self.cik = cik
    self.type_ = type_

  @property
  def params(self): 
    """Create 10-Q params"""
    return {
      'action': 'getcompany',
      'CIK': self.cik,
      'type': self.type_,
      'datea': '20000101',
      'dateb': '20200101',
      'owner': 'include',
      'count': '100',
      'output': 'atom',
    }

  def request_data(self):
    """Make request to the Website"""
    res = polite_try('https://www.sec.gov/cgi-bin/browse-edgar', params=self.params)
    print(res.url)

    return res.content

# html = Downloader('AMD', '2488', '10-Q').request_data()

# %%
### Class to parse the table and select required information
class DownloadFiling:
  def __init__(self, sym, cik, response_html, 
               save_dir='/content/drive/MyDrive/Aston/Term 3/data/10-Q-original'):
    self.sym = sym
    self.cik = cik
    self.response_html = response_html
    self.save_dir = save_dir
    self.records = None
    
  def gen_filing_url(self, acc_num):
    """generate the direct link to the txt url"""
    url = 'https://www.sec.gov/Archives/edgar/data/{cik}/{acc_num_long}/{acc_num}.txt'

    acc_num_long = acc_num.replace('-', '')
    return url.format(cik=self.cik, acc_num_long=acc_num_long, acc_num=acc_num)

  def get_records(self):
    # retreive the index 
    soup = BeautifulSoup(self.response_html, 'lxml')
    records = pd.DataFrame(columns=[
      'sym', 'cik', 'type', 'acc_num', 'filing_date', 'filing_dir', 'filing_url', 'downloaded'
    ])  # store the info 

    for entry in soup('entry'):
      # only focus on the 10-Q not 10-Q/A
      if entry.find('filing-type').text == '10-Q':
        ## details that are required
        detail = {
            'sym': self.sym, 
            'cik': self.cik, 
            'type': entry.find('filing-type').text, 
            'acc_num': entry.find('accession-number').text, 
            'filing_date': entry.find('filing-date').text,
            'filing_dir': entry.find('filing-href').text, 
            'filing_url': self.gen_filing_url(entry.find('accession-number').text), 
            'section_2_path': None, 
            'section_2_length': 0, 
            'section_1a_path': None,
            'section_1a_length': 0,
            'report_date': None,
        }
        records = records.append(pd.DataFrame(detail, index=[0]))
        self.records = records

    return records

  
  def download(self):
    """Retreive the records and download the filing """
    records = self.get_records()
    # make dir 
    try: 
      dl_dir = f'{self.save_dir}/{self.sym}'
      print(dl_dir)
      os.mkdir(dl_dir)
    except FileExistsError: 
      pass 

    # completion records 
    dl_records = pd.DataFrame()

    # download records
    for idx, record in records.iterrows():
      # request the filing 
      response = polite_try(record['filing_url'])
      print(response.status_code)
      if response.status_code == 200:

        save_name = self.sym + '-' + record['filing_url'].split('/')[-1]
        print(f'Downloaded - {dl_dir}/{save_name}')
        # write file 
        with open(f'{dl_dir}/{save_name}', 'wb') as f: 
          f.write(response.content)
        # update record
        record['downloaded'] = save_name

      # append record 
      dl_records = dl_records.append(record)
      self.records = dl_records

    return dl_records

# %%
# extracted_records = pd.DataFrame()
i = 0
for idx, company in selected_companies.iterrows():
  symbol = company['Symbol']

  # check if extracted 
  if (symbol in extracted_companies.index and 
      extracted_companies.loc[symbol][0] >= 10):
    print(symbol, '---pass')
    continue

  # # download list of links 
  html = Downloader(symbol, company['CIK'], '10-Q').request_data()

  # # download the files 
  downloader = DownloadFiling(symbol, company['CIK'], html)
  extracted_records = extracted_records.append(downloader.download())

  if i % 5 == 0:
    extracted_records.to_csv('/content/drive/MyDrive/Aston/Term 3/data/edgar-filing-new.csv')

  i += 1
# Out:
# MMM ---pass
# ABT ---pass
# ABBV ---pass
# ABMD ---pass
# ACN ---pass
# ATVI ---pass
# ADBE ---pass
# AMD ---pass
# AAP ---pass
# AES ---pass
# A ---pass
# APD ---pass
# AKAM ---pass
# ALK ---pass
# ALB ---pass
# ARE ---pass
# ALXN ---pass
# ALGN ---pass
# ALLE ---pass
# LNT ---pass
# GOOGL ---pass
# GOOG ---pass
# MO ---pass
# AMZN ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1748790&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/AMCR
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/AMCR/AMCR-0001748790-19-000007.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/AMCR/AMCR-0001104659-19-028242.txt
# AEE ---pass
# AAL ---pass
# AEP ---pass
# AMT ---pass
# AWK ---pass
# ABC ---pass
# AME ---pass
# AMGN ---pass
# APH ---pass
# ADI ---pass
# ANSS ---pass
# ANTM ---pass
# AOS ---pass
# APA ---pass
# AAPL ---pass
# AMAT ---pass
# APTV ---pass
# ADM ---pass
# ANET ---pass
# T ---pass
# ATO ---pass
# ADSK ---pass
# ADP ---pass
# AZO ---pass
# AVB ---pass
# AVY ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1701605&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-19-000089.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-19-000058.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-19-000038.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-18-000103.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-18-000082.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-18-000052.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-17-000100.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/BKR/BKR-0001701605-17-000066.txt
# BLL ---pass
# BAX ---pass
# BDX ---pass
# BBY ---pass
# BIO ---pass
# BIIB ---pass
# BA ---pass
# BKNG ---pass
# BWA ---pass
# BXP ---pass
# BSX ---pass
# BMY ---pass
# AVGO ---pass
# BR ---pass
# BF-B ---pass
# CHRW ---pass
# COG ---pass
# CDNS ---pass
# CZR ---pass
# CPB ---pass
# CAH ---pass
# KMX ---pass
# CCL ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1783180&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CARR
# CTLT ---pass
# CAT ---pass
# CBRE ---pass
# CDW ---pass
# CE ---pass
# CNC ---pass
# CNP ---pass
# CERN ---pass
# CF ---pass
# CRL ---pass
# CHTR ---pass
# CVX ---pass
# CMG ---pass
# CHD ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1739940&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CI
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CI/CI-0001739940-19-000012.txt
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CI/CI-0001739940-19-000007.txt
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CI/CI-0001104659-19-026396.txt
# CTAS ---pass
# CSCO ---pass
# CTXS ---pass
# CLX ---pass
# CMS ---pass
# KO ---pass
# CTSH ---pass
# CL ---pass
# CMCSA ---pass
# CAG ---pass
# COP ---pass
# ED ---pass
# STZ ---pass
# COO ---pass
# CPRT ---pass
# GLW ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1755672&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CTVA
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CTVA/CTVA-0001755672-19-000028.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CTVA/CTVA-0001755672-19-000014.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/CTVA/CTVA-0001755672-19-000004.txt
# COST ---pass
# CCI ---pass
# CSX ---pass
# CMI ---pass
# CVS ---pass
# DHI ---pass
# DHR ---pass
# DRI ---pass
# DVA ---pass
# DE ---pass
# DAL ---pass
# XRAY ---pass
# DVN ---pass
# DXCM ---pass
# FANG ---pass
# DLR ---pass
# DISCA ---pass
# DISCK ---pass
# DISH ---pass
# DG ---pass
# DLTR ---pass
# D ---pass
# DPZ ---pass
# DOV ---pass
# --- failure - retry (1/10)
# 403
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1751788&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DOW
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DOW/DOW-0001751788-19-000031.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DOW/DOW-0001751788-19-000023.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DOW/DOW-0001751788-19-000009.txt
# DTE ---pass
# DUK ---pass
# DRE ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1666700&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-19-000073.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-19-000065.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-19-000019.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-18-000060.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-18-000041.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-18-000025.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DD/DD-0001666700-17-000026.txt
# DXC ---pass
# EMN ---pass
# ETN ---pass
# EBAY ---pass
# ECL ---pass
# EIX ---pass
# EW ---pass
# EA ---pass
# EMR ---pass
# ENPH ---pass
# ETR ---pass
# EOG ---pass
# EFX ---pass
# EQIX ---pass
# EQR ---pass
# ESS ---pass
# EL ---pass
# ETSY ---pass
# --- failure - retry (1/10)
# 403
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1711269&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/EVRG
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/EVRG/EVRG-0001711269-19-000063.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/EVRG/EVRG-0001711269-19-000048.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/EVRG/EVRG-0001711269-19-000034.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/EVRG/EVRG-0001711269-18-000022.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/EVRG/EVRG-0001711269-18-000012.txt
# ES ---pass
# EXC ---pass
# EXPE ---pass
# EXPD ---pass
# EXR ---pass
# XOM ---pass
# FFIV ---pass
# FB ---pass
# FAST ---pass
# FRT ---pass
# FDX ---pass
# FIS ---pass
# FE ---pass
# FISV ---pass
# FLT ---pass
# FMC ---pass
# F ---pass
# FTNT ---pass
# FTV ---pass
# FBHS ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1754301&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOXA
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOXA/FOXA-0001564590-19-041135.txt
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOXA/FOXA-0001564590-19-018565.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOXA/FOXA-0001564590-19-008308.txt
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1754301&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOX
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOX/FOX-0001564590-19-041135.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOX/FOX-0001564590-19-018565.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/FOX/FOX-0001564590-19-008308.txt
# FCX ---pass
# GPS ---pass
# GRMN ---pass
# IT ---pass
# GNRC ---pass
# GD ---pass
# GE ---pass
# GIS ---pass
# GM ---pass
# GPC ---pass
# GILD ---pass
# GPN ---pass
# GWW ---pass
# HAL ---pass
# HBI ---pass
# HAS ---pass
# HCA ---pass
# PEAK ---pass
# HSIC ---pass
# HSY ---pass
# HES ---pass
# HPE ---pass
# HLT ---pass
# HOLX ---pass
# HD ---pass
# HON ---pass
# HRL ---pass
# HST ---pass
# HWM ---pass
# HPQ ---pass
# HUM ---pass
# HII ---pass
# IEX ---pass
# IDXX ---pass
# INFO ---pass
# ITW ---pass
# ILMN ---pass
# INCY ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1699150&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-19-019437.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-19-014130.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-19-008046.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-18-041472.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-18-035393.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-18-020162.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-17-039786.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/IR/IR-0001140361-17-030148.txt
# INTC ---pass
# IBM ---pass
# IP ---pass
# IPG ---pass
# IFF ---pass
# INTU ---pass
# ISRG ---pass
# IPGP ---pass
# IQV ---pass
# IRM ---pass
# JKHY ---pass
# J ---pass
# JBHT ---pass
# SJM ---pass
# JNJ ---pass
# JCI ---pass
# JNPR ---pass
# KSU ---pass
# K ---pass
# KEYS ---pass
# KMB ---pass
# KIM ---pass
# KMI ---pass
# KLAC ---pass
# KHC ---pass
# KR ---pass
# LB ---pass
# LHX ---pass
# LH ---pass
# LRCX ---pass
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1679273&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-19-008763.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-19-002742.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-19-000033.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-18-007616.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-18-002794.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-18-000022.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-17-007269.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-17-002479.txt
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LW/LW-0001558370-17-000080.txt
# LVS ---pass
# LEG ---pass
# LDOS ---pass
# LEN ---pass
# LLY ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1707925&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LIN
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LIN/LIN-0001707925-19-000076.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LIN/LIN-0001707925-19-000059.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LIN/LIN-0001628280-19-006519.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LIN/LIN-0001707925-18-000033.txt
# --- failure - retry (1/10)
# 403
# --- failure - retry (2/10)
# 403
# --- failure - retry (3/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/LIN/LIN-0001707925-17-000008.txt
# LYV ---pass
# LKQ ---pass
# LMT ---pass
# LOW ---pass
# LUMN ---pass
# LYB ---pass
# MRO ---pass
# MPC ---pass
# MAR ---pass
# MLM ---pass
# MAS ---pass
# MA ---pass
# MKC ---pass
# MXIM ---pass
# MCD ---pass
# MCK ---pass
# MDT ---pass
# MRK ---pass
# MTD ---pass
# MGM ---pass
# MCHP ---pass
# MU ---pass
# MSFT ---pass
# MAA ---pass
# MHK ---pass
# TAP ---pass
# MDLZ ---pass
# MPWR ---pass
# MNST ---pass
# MOS ---pass
# MSI ---pass
# NTAP ---pass
# NFLX ---pass
# NWL ---pass
# NEM ---pass
# NWSA ---pass
# NWS ---pass
# NEE ---pass
# NLSN ---pass
# NKE ---pass
# NI ---pass
# NSC ---pass
# NOC ---pass
# NLOK ---pass
# NCLH ---pass
# NOV ---pass
# NRG ---pass
# NUE ---pass
# NVDA ---pass
# NVR ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1413447&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/NXPI
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/NXPI/NXPI-0001413447-19-000035.txt
# ORLY ---pass
# OXY ---pass
# ODFL ---pass
# OMC ---pass
# OKE ---pass
# ORCL ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1821825&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/OGN
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1781335&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/OTIS
# PCAR ---pass
# PKG ---pass
# PH ---pass
# PAYX ---pass
# PAYC ---pass
# PYPL ---pass
# PENN ---pass
# PNR ---pass
# PEP ---pass
# PKI ---pass
# PRGO ---pass
# PFE ---pass
# PM ---pass
# PSX ---pass
# PNW ---pass
# PXD ---pass
# POOL ---pass
# PPG ---pass
# PPL ---pass
# PG ---pass
# PLD ---pass
# PTC ---pass
# PEG ---pass
# PSA ---pass
# PHM ---pass
# PVH ---pass
# QRVO ---pass
# PWR ---pass
# QCOM ---pass
# DGX ---pass
# RL ---pass
# RTX ---pass
# O ---pass
# REG ---pass
# REGN ---pass
# RSG ---pass
# RMD ---pass
# RHI ---pass
# ROK ---pass
# ROL ---pass
# ROP ---pass
# ROST ---pass
# RCL ---pass
# CRM ---pass
# SBAC ---pass
# SLB ---pass
# STX ---pass
# SEE ---pass
# SRE ---pass
# NOW ---pass
# SHW ---pass
# SPG ---pass
# SWKS ---pass
# SNA ---pass
# SO ---pass
# LUV ---pass
# SWK ---pass
# SBUX ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1757898&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/STE
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/STE/STE-0001757898-19-000018.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/STE/STE-0001757898-19-000012.txt
# SYK ---pass
# SNPS ---pass
# SYY ---pass
# TMUS ---pass
# TTWO ---pass
# TPR ---pass
# TGT ---pass
# TEL ---pass
# TDY ---pass
# TFX ---pass
# TER ---pass
# TSLA ---pass
# TXN ---pass
# TXT ---pass
# TMO ---pass
# TJX ---pass
# TSCO ---pass
# TT ---pass
# TDG ---pass
# TRMB ---pass
# TWTR ---pass
# TYL ---pass
# TSN ---pass
# UDR ---pass
# ULTA ---pass
# UAA ---pass
# UA ---pass
# UNP ---pass
# UAL ---pass
# UNH ---pass
# UPS ---pass
# URI ---pass
# UHS ---pass
# VLO ---pass
# VTR ---pass
# VRSN ---pass
# VRSK ---pass
# VZ ---pass
# VRTX ---pass
# VFC ---pass
# VIAC ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1792044&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/VTRS
# V ---pass
# VNO ---pass
# VMC ---pass
# WAB ---pass
# WMT ---pass
# WBA ---pass
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1744489&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DIS
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DIS/DIS-0001744489-19-000167.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/DIS/DIS-0001744489-19-000100.txt
# WM ---pass
# WAT ---pass
# WEC ---pass
# WELL ---pass
# WST ---pass
# WDC ---pass
# WU ---pass
# --- failure - retry (1/10)
# 403
# https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1732845&type=10-Q&datea=20000101&dateb=20200101&owner=include&count=100&output=atom
# /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/WRK
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/WRK/WRK-0001564590-19-028404.txt
# --- failure - retry (1/10)
# 403
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/WRK/WRK-0001564590-19-015459.txt
# 200
# Downloaded - /content/drive/MyDrive/Aston/Term 3/data/10-Q-original/WRK/WRK-0001564590-19-002324.txt
# WY ---pass
# WHR ---pass
# WMB ---pass
# WYNN ---pass
# XEL ---pass
# XLNX ---pass
# XYL ---pass
# YUM ---pass
# ZBRA ---pass
# ZBH ---pass
# ZTS ---pass

# %%
extracted_records.to_csv('/content/drive/MyDrive/Aston/Term 3/data/edgar-filing-new.csv')
